# %%
import pandas as pd

df = pd.read_csv('players_20.csv')
#set Index
df.set_index('short_name',inplace=True)
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
# select columns
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#Get all data about L.Messi
df.loc['L. Messi']
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
# dob                                1987-06-24
# height_cm                                 170
# weight_kg                                  72
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, dtype: object

# %%
#Get the heught of Messi
df.loc['L. Messi','height_cm']
# Out:
# np.int64(170)

# %%
#Get all rows insife the heught column
df.loc[:,'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
#Get all data about L.Messi and Cristiano Ronaldo
df.loc[['L. Messi','Cristiano Ronaldo']]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
players=['L. Messi','Cristiano Ronaldo']

df.loc[players,'age':'club']
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus

# %% [markdown]
# ## Set a new value to one cell

# %%
#update the hight of L. Messi
df.loc['L. Messi','height_cm'] =175

# %%
#show to dataFrame
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#set height of all player to 190
df.loc[:,'height_cm'] =190
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# ## Drop Rows OR Columns

# %%
#Drop one row
df.drop('L. Messi',axis=0)

#Drop tow or more rows
df.drop(['L. Messi','Cristiano Ronaldo'],axis=0)
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior   27  1992-02-05        190
# J. Oblak                           Jan Oblak   26  1993-01-07        190
# E. Hazard                        Eden Hazard   28  1991-01-07        190
# K. De Bruyne                 Kevin De Bruyne   28  1991-06-28        190
# M. ter Stegen          Marc-André ter Stegen   27  1992-04-30        190
# ...                                      ...  ...         ...        ...
# Shao Shuai                                邵帅   22  1997-03-10        190
# Xiao Mingjie                    Mingjie Xiao   22  1997-01-01        190
# Zhang Wei                                 张威   19  2000-05-16        190
# Wang Haijian                             汪海健   18  2000-08-02        190
# Pan Ximing                               潘喜明   26  1993-01-11        190
#
#                weight_kg nationality                           club
# ...

# %%
#Drop one col
df.drop('long_name',axis=1)
#drop the last col
df.drop(df.columns[[-1]],axis=1)

#Drop tow or more cols
df.drop(['long_name','dob'],axis=1)
# Out:
#                    age  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32        190         72   Argentina
# Cristiano Ronaldo   34        190         83    Portugal
# Neymar Jr           27        190         68      Brazil
# J. Oblak            26        190         87    Slovenia
# E. Hazard           28        190         74     Belgium
# ...                ...        ...        ...         ...
# Shao Shuai          22        190         79    China PR
# Xiao Mingjie        22        190         66    China PR
# Zhang Wei           19        190         75    China PR
# Wang Haijian        18        190         74    China PR
# Pan Ximing          26        190         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# ...

# %% [markdown]
# ## Create a Random Sample

# %%
# Extract 10 random elemnts from the nationality col
df['nationality'].sample(10)
# Out:
# short_name
# J. Swift                       England
# J. Cavallaro                 Argentina
# N. Spolli                    Argentina
# U. Bapoh                       Germany
# Kim Tae Han             Korea Republic
# E. Barreto                    Paraguay
# Yohan Tavares                 Portugal
# Iñigo Martínez                   Spain
# D. Herazo                     Colombia
# A. Barman         United Arab Emirates
# Name: nationality, dtype: object

# %%
#Random 20% form df
df.sample(frac=0.2,random_state=1)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# D. Cvetinović                Dušan Cvetinović   30  1988-12-24        190
# M. Silva                        Marcelo Silva   30  1989-03-21        190
# S. Mandash               Sultan Ahmed Mandash   24  1994-10-17        190
# I. Gruev                           Ilia Gruev   19  2000-05-06        190
# Kangin Lee                     이강인 Kangin Lee   18  2001-02-19        190
# ...                                       ...  ...         ...        ...
# P. Finger                      Patrick Finger   18  2001-01-01        190
# T. Băluță                        Tudor Băluță   20  1999-03-27        190
# Adrián Maideira  Adrián Guto Maideira Almeida   35  1984-02-29        190
# Choi Chul Soon                        최철순 崔喆淳   32  1987-02-08        190
# K. Agard                         Kieran Agard   29  1989-10-10        190
#
#                  weight_kg     nationality                    club
# ...

# %%
#avec reptition
df.sample(frac=0.2,replace=True,random_state=1)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# Josué Chiamulera  Josué Durval Chiamulera Vaz   27  1992-02-29        190
# A. Gündüz                       Atakan Gündüz   18  2001-01-01        190
# L. Sadiku                        Loret Sadiku   27  1991-07-28        190
# M. Leverbe                     Maxime Leverbe   22  1997-02-15        190
# S. Ichazo                     Salvador Ichazo   27  1992-01-26        190
# ...                                       ...  ...         ...        ...
# T. Vollnhofer               Thomas Vollnhofer   34  1984-09-02        190
# V. Demaku                        Vesel Demaku   19  2000-02-05        190
# D. Dudziński                 Daniel Dudziński   17  2002-03-07        190
# M. Saito                                 齋藤 学   29  1990-04-04        190
# Z. Touré                          Zargo Touré   29  1989-11-11        190
#
#                   weight_kg nationality               club
# ...

# %% [markdown]
# ## Filter with query()

# %%
#select player older than34 
df.query("age>=34")
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# G. Chiellini                         Giorgio Chiellini   34  1984-08-14
# S. Handanovič                         Samir Handanovič   34  1984-07-14
# Fernandinho                         Fernando Luiz Rosa   34  1985-05-04
# Thiago Silva                  Thiago Emiliano da Silva   34  1984-09-22
# ...                                                ...  ...         ...
# N. Hunt                                     Nicky Hunt   35  1983-09-03
# K. Ogi                                            荻 晃太   36  1983-05-05
# J. McCombe                              Jamie  McCombe   36  1983-01-01
# G. Maley                                    Gary Maley   36  1982-08-03
# Zhou Ting                                           周挺   40  1979-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# ...

# %%
#select players older than 34 from Italy
df.query("age>=34 and nationality=='Italy' ")
# Out:
#                             long_name  age         dob  height_cm  weight_kg  \
# short_name
# G. Chiellini        Giorgio Chiellini   34  1984-08-14        190         85
# G. Buffon            Gianluigi Buffon   41  1978-01-28        190         92
# F. Quagliarella    Fabio Quagliarella   36  1983-01-31        190         79
# D. De Rossi          Daniele De Rossi   35  1983-07-24        190         83
# M. Parolo                Marco Parolo   34  1985-01-25        190         75
# A. Mirante            Antonio Mirante   35  1983-07-08        190         79
# A. Diamanti       Alessandro Diamanti   36  1983-05-02        190         75
# L. Rigoni                 Luca Rigoni   34  1984-12-07        190         75
# E. Giaccherini   Emanuele Giaccherini   34  1985-05-05        190         60
# C. Maggio            Christian Maggio   37  1982-02-11        190         79
# F. Magnanelli    Francesco Magnanelli   34  1984-11-12        190         79
# ...

# %%
#Add not oprator to the first query
df.query("not(age>=34)")
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# L. Messi      Lionel Andrés Messi Cuccittini   32  1987-06-24        190
# Neymar Jr      Neymar da Silva Santos Junior   27  1992-02-05        190
# J. Oblak                           Jan Oblak   26  1993-01-07        190
# E. Hazard                        Eden Hazard   28  1991-01-07        190
# K. De Bruyne                 Kevin De Bruyne   28  1991-06-28        190
# ...                                      ...  ...         ...        ...
# Shao Shuai                                邵帅   22  1997-03-10        190
# Xiao Mingjie                    Mingjie Xiao   22  1997-01-01        190
# Zhang Wei                                 张威   19  2000-05-16        190
# Wang Haijian                             汪海健   18  2000-08-02        190
# Pan Ximing                               潘喜明   26  1993-01-11        190
#
#               weight_kg nationality                           club
# short_name
# ...

# %%
#convert height to meters and select those with height above 1.8
df.query("height_cm/100>1.8")
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#select players that were born after 1990

#check out data types
df.dtypes
#conver 'dob' col datetime type
df['dob'] = df['dob'].astype('datetime64[ns]')

#query

df.query('dob.dt.year >1990')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13092\2692716788.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dob'] = df['dob'].astype('datetime64[ns]')
#                                    long_name  age        dob  height_cm  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior   27 1992-02-05        190
# J. Oblak                           Jan Oblak   26 1993-01-07        190
# E. Hazard                        Eden Hazard   28 1991-01-07        190
# K. De Bruyne                 Kevin De Bruyne   28 1991-06-28        190
# M. ter Stegen          Marc-André ter Stegen   27 1992-04-30        190
# ...                                      ...  ...        ...        ...
# ...

# %% [markdown]
# #### Aplly method

# %%
#use numpy fun and apply it to series
import numpy as np
df['age'].apply(np.sqrt)
# Out:
# short_name
# L. Messi             5.656854
# Cristiano Ronaldo    5.830952
# Neymar Jr            5.196152
# J. Oblak             5.099020
# E. Hazard            5.291503
#                        ...
# Shao Shuai           4.690416
# Xiao Mingjie         4.690416
# Zhang Wei            4.358899
# Wang Haijian         4.242641
# Pan Ximing           5.099020
# Name: age, Length: 18278, dtype: float64

# %%
#creat your own fun and apply it to  a data frame
def calc_bmi(row):
    return row['weight_kg']/(row['height_cm']/100)**2
df.apply(calc_bmi,axis=1)
# Out:
# short_name
# L. Messi             19.944598
# Cristiano Ronaldo    22.991690
# Neymar Jr            18.836565
# J. Oblak             24.099723
# E. Hazard            20.498615
#                        ...
# Shao Shuai           21.883657
# Xiao Mingjie         18.282548
# Zhang Wei            20.775623
# Wang Haijian         20.498615
# Pan Ximing           21.606648
# Length: 18278, dtype: float64

# %% [markdown]
# ## Lambda fun

# %%
#lambda fun one line
sum_lambda = lambda a,b:a+b

sum_lambda(2,3)
# Out:
# 5

# %%
df['height_cm'].apply(lambda x:x/100)
# Out:
# short_name
# L. Messi             1.9
# Cristiano Ronaldo    1.9
# Neymar Jr            1.9
# J. Oblak             1.9
# E. Hazard            1.9
#                     ...
# Shao Shuai           1.9
# Xiao Mingjie         1.9
# Zhang Wei            1.9
# Wang Haijian         1.9
# Pan Ximing           1.9
# Name: height_cm, Length: 18278, dtype: float64

# %%
df['long_name'].apply(lambda x:x.upper())
# Out:
# short_name
# L. Messi                  LIONEL ANDRÉS MESSI CUCCITTINI
# Cristiano Ronaldo    CRISTIANO RONALDO DOS SANTOS AVEIRO
# Neymar Jr                  NEYMAR DA SILVA SANTOS JUNIOR
# J. Oblak                                       JAN OBLAK
# E. Hazard                                    EDEN HAZARD
#                                     ...
# Shao Shuai                                            邵帅
# Xiao Mingjie                                MINGJIE XIAO
# Zhang Wei                                             张威
# Wang Haijian                                         汪海健
# Pan Ximing                                           潘喜明
# Name: long_name, Length: 18278, dtype: object

# %%
df['dob'].apply(lambda x:x.month)
# Out:
# short_name
# L. Messi             6
# Cristiano Ronaldo    2
# Neymar Jr            2
# J. Oblak             1
# E. Hazard            1
#                     ..
# Shao Shuai           3
# Xiao Mingjie         1
# Zhang Wei            5
# Wang Haijian         8
# Pan Ximing           1
# Name: dob, Length: 18278, dtype: int64

# %% [markdown]
# ### Copy

# %%
df.copy() #this is not rolated

df.copy(deep=False) #rolated

# %% [markdown]
# ### Pivot Table
