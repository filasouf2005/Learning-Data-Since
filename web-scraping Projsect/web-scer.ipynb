# %%
import pandas as pd

# %% [markdown]
# Target web : [website](https://www.football-data.co.uk/data.php)

# %%
import sys
print(sys.executable)
print(sys.version)

# %%
import pandas as pd

df = pd.read_csv('https://www.football-data.co.uk/mmz4281/2526/E0.csv')

df.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# 2     1.96     1.91     2.08
# 3     1.78     2.02     1.97
# 4     1.83     2.07     1.92
#
# [5 rows x 132 columns]

# %%
df
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00       Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30     Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00        Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00      Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00       Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...             ...          ...   ...   ...  ..   ...
# 125  E0  30/11/2025  12:00  Crystal Palace   Man United     1     2   A     1
# 126  E0  30/11/2025  14:05     Aston Villa       Wolves     1     0   H     0
# 127  E0  30/11/2025  14:05   Nott'm Forest     Brighton     0     2   A     0
# 128  E0  30/11/2025  14:05        West Ham    Liverpool     0     2   A     0
# 129  E0  30/11/2025  16:30         Chelsea      Arsenal     1     1   D     0
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1       0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2       0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3       0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4       0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
# ..    ...  ...      ...      ...    ...    ...      ...      ...      ...
# 125     0  ...     2.05     1.75   2.10   1.83     2.35     1.81     2.10
# 126     0  ...     2.05     1.75   2.12   1.82     2.05     1.88     1.98
# 127     1  ...     2.10     1.70   2.11   1.83     2.10     1.83     2.03
# 128     0  ...     1.93     1.93   1.95   1.97     1.93     1.93     1.88
# 129     0  ...     1.68     2.15   1.81   2.14     1.75     2.15     1.71
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       1.76     2.14     1.86
# 1       1.74     2.14     1.86
# 2       1.96     1.91     2.08
# 3       1.78     2.02     1.97
# 4       1.83     2.07     1.92
# ..       ...      ...      ...
# 125     1.71     2.15     1.86
# 126     1.79     2.18     1.83
# 127     1.74     2.12     1.87
# 128     1.90     1.98     2.01
# 129     2.02     1.86     2.15
#
# [130 rows x 132 columns]

# %%
#rename the dataFrame 
df.rename(columns={'FTHG':'home_goals','FTAG':'away_goals'},inplace=True)
df
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00       Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30     Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00        Brighton       Fulham           1
# 3    E0  16/08/2025  15:00      Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00       Tottenham      Burnley           3
# ..   ..         ...    ...             ...          ...         ...
# 125  E0  30/11/2025  12:00  Crystal Palace   Man United           1
# 126  E0  30/11/2025  14:05     Aston Villa       Wolves           1
# 127  E0  30/11/2025  14:05   Nott'm Forest     Brighton           0
# 128  E0  30/11/2025  14:05        West Ham    Liverpool           0
# 129  E0  30/11/2025  16:30         Chelsea      Arsenal           1
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# 1             0   D     0     0  ...     2.05     1.80   2.02   1.89     2.06
# 2             1   D     0     0  ...     1.83     2.03   1.93   2.00     1.84
# 3             0   H     0     0  ...     1.95     1.90   1.97   1.95     1.95
# 4             0   H     1     0  ...     1.98     1.88   1.99   1.93     1.98
# ..          ...  ..   ...   ...  ...      ...      ...    ...    ...      ...
# 125           2   A     1     0  ...     2.05     1.75   2.10   1.83     2.35
# 126           0   H     0     0  ...     2.05     1.75   2.12   1.82     2.05
# 127           2   A     0     1  ...     2.10     1.70   2.11   1.83     2.10
# 128           2   A     0     0  ...     1.93     1.93   1.95   1.97     1.93
# 129           1   D     0     0  ...     1.68     2.15   1.81   2.14     1.75
#
#      MaxCAHA  AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# 0       1.88     1.94     1.76     2.14     1.86
# 1       1.80     1.95     1.74     2.14     1.86
# 2       2.03     1.80     1.96     1.91     2.08
# 3       1.94     1.86     1.78     2.02     1.97
# 4       1.91     1.88     1.83     2.07     1.92
# ..       ...      ...      ...      ...      ...
# 125     1.81     2.10     1.71     2.15     1.86
# 126     1.88     1.98     1.79     2.18     1.83
# 127     1.83     2.03     1.74     2.12     1.87
# 128     1.93     1.88     1.90     1.98     2.01
# 129     2.15     1.71     2.02     1.86     2.15
#
# [130 rows x 132 columns]

# %% [markdown]
# ## Read .csv from Multiple URLs with Pandas

# %% [markdown]
# "https://www.football-data.co.uk/mmz4281/2526/E0.csv"

# %%
#create a root var
root = "https://www.football-data.co.uk/mmz4281/"
#creat a list of leagues
leagues =['E0','E2','E3']
frames =[]

# looping through leagues, read multiple csv and append it into a list 
for league in leagues :
    for season in range(20,25):
        df = pd.read_csv(root + str(season) + str(season+1) + '/'+ league +'.csv',encoding='unicode_escape' )
        df.insert(1,'season',season)
        frames.append(df)

# %%
#lenght of fream
len(frames)
# Out:
# 15

# %%
#show the first index
frames[5]
# Out:
#     Div  season        Date   Time            HomeTeam            AwayTeam  \
# 0    E2      20  12/09/2020  15:00          Accrington           Peterboro
# 1    E2      20  12/09/2020  15:00               Crewe            Charlton
# 2    E2      20  12/09/2020  15:00           Doncaster  Milton Keynes Dons
# 3    E2      20  12/09/2020  15:00      Fleetwood Town              Burton
# 4    E2      20  12/09/2020  15:00          Gillingham                Hull
# ..   ..     ...         ...    ...                 ...                 ...
# 547  E2      20  09/05/2021  12:00  Milton Keynes Dons            Rochdale
# 548  E2      20  09/05/2021  12:00              Oxford              Burton
# 549  E2      20  09/05/2021  12:00          Portsmouth          Accrington
# 550  E2      20  09/05/2021  12:00          Sunderland         Northampton
# 551  E2      20  09/05/2021  12:00               Wigan             Swindon
#
#      FTHG  FTAG FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  \
# 0       2     0   H     1  ...      2.03  0.25     2.02      1.83   2.08
# 1       0     2   A     0  ...      1.88  0.00     1.95      1.90   1.96
# 2       1     1   D     0  ...      1.69 -0.25     1.80      2.05   1.81
# 3       2     1   H     1  ...      1.85 -0.50     1.98      1.88   1.95
# 4       0     2   A     0  ...      1.86  0.00     1.85      2.00   1.91
# ..    ...   ...  ..   ...  ...       ...   ...      ...       ...    ...
# 547     0     3   A     0  ...      2.56 -0.75     1.88      1.98   1.88
# 548     4     0   H     2  ...      2.38 -1.00     1.85      2.00   1.88
# 549     0     1   A     0  ...      2.21 -1.00     1.95      1.90   1.99
# 550     1     1   D     0  ...      2.13 -1.25     1.98      1.88   2.02
# 551     3     4   A     1  ...      2.28 -0.75     1.93      1.93   2.00
#
#      PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.83     2.09     1.87     2.02     1.81
# 1     1.94     2.00     1.95     1.94     1.89
# 2     2.12     1.85     2.12     1.80     2.05
# 3     1.95     2.06     1.95     1.97     1.86
# 4     2.00     1.93     2.06     1.85     1.99
# ..     ...      ...      ...      ...      ...
# 547   2.01     1.96     2.04     1.87     1.97
# 548   2.02     2.11     2.06     1.88     1.95
# 549   1.90     2.07     1.94     1.95     1.88
# 550   1.88     2.10     1.91     2.01     1.83
# 551   1.88     2.01     1.97     1.93     1.90
#
# [552 rows x 107 columns]

# %%
# create a dictionary with original name of league as key
dict_countries = {
              'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
              'German Bundesliga':'D1', 
              'English Premier League':'E0', 'English League 1':'E2', 'English League 2':'E3',
             }

dict_historical_data = {} 

# looping through key elements
for league in dict_countries:
    frames = [] # one dataframe per league
    for season in range(15, 21):
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
        df.insert(1, 'season', season)
        frames.append(df)
    df_frames = pd.concat(frames) # storing all seasons of a league in a single dataframe
    dict_historical_data[league] = df_frames # assigning dataframe to a new dictionary

# %%
#showing dataFrame
dict_historical_data['Spanish La Liga']
# Out:
#      Div  season        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1      15    21/08/15       Malaga     Sevilla     0     0   D     0
# 1    SP1      15    22/08/15   Ath Madrid  Las Palmas     1     0   H     1
# 2    SP1      15    22/08/15      Espanol      Getafe     1     0   H     1
# 3    SP1      15    22/08/15    La Coruna    Sociedad     0     0   D     0
# 4    SP1      15    22/08/15    Vallecano    Valencia     0     0   D     0
# ..   ...     ...         ...          ...         ...   ...   ...  ..   ...
# 375  SP1      20  22/05/2021      Osasuna    Sociedad     0     1   A     0
# 376  SP1      20  22/05/2021  Real Madrid  Villarreal     2     1   H     0
# 377  SP1      20  22/05/2021   Valladolid  Ath Madrid     1     2   A     1
# 378  SP1      20  23/05/2021      Granada      Getafe     0     0   D     0
# 379  SP1      20  23/05/2021      Sevilla      Alaves     1     0   H     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 1       0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 2       0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 3       0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 4       0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# ..    ...  ...      ...   ...       ...       ...    ...    ...      ...
# 375     0  ...     2.34  1.00      2.07      1.86   2.06   1.87     2.07
# 376     1  ...     2.57 -1.00      2.01      1.92   2.00   1.93     2.02
# 377     0  ...     2.30  1.50      1.90      2.03   1.90   2.02     1.95
# 378     0  ...     1.80  0.25      1.73      2.08   1.77   2.18     1.84
# 379     0  ...     2.40 -1.50      1.97      1.96   1.93   1.99     2.13
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0        NaN      NaN      NaN
# 1        NaN      NaN      NaN
# 2        NaN      NaN      NaN
# 3        NaN      NaN      NaN
# 4        NaN      NaN      NaN
# ..       ...      ...      ...
# 375     1.96     1.98     1.88
# 376     2.02     1.95     1.92
# 377     2.06     1.90     1.97
# 378     2.23     1.77     2.12
# 379     2.03     1.99     1.88
#
# [2280 rows x 127 columns]

# %% [markdown]
# ### Filter DataFrame
